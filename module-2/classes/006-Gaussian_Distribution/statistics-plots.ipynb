# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data/vehicles_v2.csv')

# %%
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# # Boxplot

# %%
import matplotlib.pyplot as plt

# %%
data.describe().loc[['mean','50%']].T
# Out:
#                                  mean          50%
# Year                      2000.716400  2001.000000
# Engine Displacement          3.338493     3.000000
# Cylinders                    5.765076     6.000000
# Fuel Barrels/Year           17.609056    17.347895
# City MPG                    17.646139    17.000000
# Highway MPG                 23.880646    24.000000
# Combined MPG                19.929322    19.000000
# CO2 Emission Grams/Mile    475.316339   467.736842
# Fuel Cost/Year            1892.598465  1850.000000
# Price                    10007.498745  6934.365807

# %%
data.boxplot(column="Price");

# %%
sns.boxplot(data['Price'])

# %%
sns.distplot(data['Price'])
plt.vlines(data['Price'].mean(), 0, 0.0001)
plt.vlines(data['Price'].median(), 0, 0.0001)

# %%
from scipy.stats import kurtosistest

# %%
data['Price'].kurtosis()
# Out:
# 6.106892589997627

# %%
# standardization
# sns.distplot(((data['Price'] - data['Price'].mean())/data['Price'].std()))

# %%
import seaborn as sns

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
sns.distplot(data['Highway MPG'])

# %%
plt.figure(figsize=(12, 12))
ax = sns.boxplot(x="Fuel Type", y="Highway MPG", data=data, )
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# whiskers
# some of the boxplots have no outlier cutoff (bigodinho) because they exceed the maximum or minimum

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,8), sharey=True)

sns.boxplot(x="Fuel Type", y="Highway MPG", data=data.query('`Fuel Type` == "Diesel"'), ax=axes[0])
sns.boxplot(x="Fuel Type", y="City MPG", data=data.query('`Fuel Type` == "Diesel"'), ax=axes[1], )

# %%
# Quando não compartilho o eixo y, a comparação não é válida.

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,8), )

sns.boxplot(x="Fuel Type", y="Highway MPG", data=data.query('`Fuel Type` == "Diesel"'), ax=axes[0])
sns.boxplot(x="Fuel Type", y="City MPG", data=data.query('`Fuel Type` == "Diesel"'), ax=axes[1], )

# %%
fuel_type = data["Fuel Type"]
mpg = data["Highway MPG"]

# %%
ax = sns.boxplot(x=fuel_type, y=mpg)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
filtered_data = data.query('Cylinders in (6, 4)')
filtered_data.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year        Price
# 0               522.764706            1950  5069.372132
# 1               683.615385            2550  1003.281232

# %%
fig, ax = plt.subplots(figsize=(16,9))

# Now we can use the box plot on tis new data-frame as shown below:

sns.boxplot(x="Fuel Type", y="Highway MPG", hue="Cylinders",data=filtered_data, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
import seaborn as sns
sns.violinplot("Combined MPG", data=data)

# %%
data['Fuel Barrels/Year'].hist()

# %%
data['Fuel Barrels/Year'].hist(bins=50)

# %%
data['Fuel Barrels/Year'].plot(kind='hist')

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data['Fuel Barrels/Year'].iplot(kind='hist', bins=50)
# Out:
# <div>
#
#
#             <div id="b1e8d481-d6ab-4a42-b43f-c0d9d5094aca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b1e8d481-d6ab-4a42-b43f-c0d9d5094aca")) {
#                     Plotly.newPlot(
#                         'b1e8d481-d6ab-4a42-b43f-c0d9d5094aca',
# ...

# %%
x = data['Fuel Barrels/Year']
sns.distplot(x);

# %%
x.plot(kind='kde',)

# %%
sns.distplot(x, bins=20)

# %% [markdown]
# # Value Counts

# %%
data['Drivetrain'].unique()
# Out:
# array(['2-Wheel Drive', 'Rear-Wheel Drive', 'Front-Wheel Drive',
#        '4-Wheel or All-Wheel Drive', 'All-Wheel Drive', '4-Wheel Drive',
#        'Part-time 4-Wheel Drive', '2-Wheel Drive, Front'], dtype=object)

# %%
data['Drivetrain'].value_counts()
# Out:
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %%
data['Drivetrain'].value_counts(normalize=True)
# Out:
# Front-Wheel Drive             0.362817
# Rear-Wheel Drive              0.353972
# 4-Wheel or All-Wheel Drive    0.180880
# All-Wheel Drive               0.056715
# 4-Wheel Drive                 0.029428
# 2-Wheel Drive                 0.011766
# Part-time 4-Wheel Drive       0.004395
# 2-Wheel Drive, Front          0.000028
# Name: Drivetrain, dtype: float64

# %%
data['Drivetrain'].value_counts().plot(kind='bar')

# %%
sns.countplot(data['Drivetrain'])

# %%
fig, ax = plt.subplots()
sns.countplot(data['Drivetrain'] , ax=ax, color='blue')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
ax = sns.barplot(x="Fuel Type", y="Highway MPG", hue="Cylinders", data=filtered_data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# # Effect of a category variable

# %%
data.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year        Price
# 0               522.764706            1950  5069.372132
# 1               683.615385            2550  1003.281232

# %%
sns.distplot(data['Combined MPG'])

# %%
plt.figure(figsize=(12,8))
sns.distplot(data.query('Cylinders == 4')['Combined MPG'], label='4')
sns.distplot(data.query('Cylinders == 6')['Combined MPG'], label='6')
plt.legend()

# %%
plt.figure(figsize=(12,8))
sns.distplot(data.query('Cylinders == 4')['Price'], label='4', hist=False)
sns.distplot(data.query('Cylinders == 6')['Price'], label='6', hist=False)
plt.legend()

# %% [markdown]
# ## Catplot

# %%
g = sns.catplot(x="Cylinders", y="CO2 Emission Grams/Mile",
                data=data.sample(1000), #saturation=.5, 
                kind="swarm", ci=None, aspect=.6, height=10)

# %%
data.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year        Price
# 0               522.764706            1950  5069.372132
# 1               683.615385            2550  1003.281232

# %%
g = sns.catplot(x="Cylinders", y="CO2 Emission Grams/Mile", col='Transmission', col_wrap=5,
                data=data, #saturation=.5, 
                kind="bar", ci=None, aspect=.6, height=5)

# %% [markdown]
# # Visually comparing to normal distribution

# %% [markdown]
# ## ProbPlot

# %% [markdown]
# The prob-plot compares any distribution to the normal distribution (straight line)

# %%
x = np.random.gamma(0.25, size=100000)
sns.distplot(x, hist=False)
sns.distplot(np.random.normal(size=100000), hist=False)

# %%
import matplotlib.pyplot as plt
from scipy import stats
fig, ax = plt.subplots(1,1, figsize=(12,8))

val = stats.probplot(x ,plot=ax)

# %%
sns.distplot(data['CO2 Emission Grams/Mile'])
data['CO2 Emission Grams/Mile'].kurtosis()
# Out:
# 1.263582798473081

# %%
fig, ax = plt.subplots(1,1, figsize=(12,8))

stats.probplot(data['CO2 Emission Grams/Mile'], plot=ax);

# %%
fig, ax = plt.subplots(1,1, figsize=(12,8))

stats.probplot(data['Price'], plot=ax);

# %% [markdown]
# ## Applying a transformation on my dataset

# %% [markdown]
# ## Which ones could help?

# %% [markdown]
# ### Transformation 1: Tirar o logaritmo da minha coluna
#
# ### Transformation 2: Tirar a raiz quadrada

# %%
transformed_data = np.log10(data['Price'])

# %%
fig, ax = plt.subplots(1,1, figsize=(12,8))
val = stats.probplot(transformed_data, plot=ax)

# %%
sns.distplot(np.log10(data['Price']))

# %%
# sqrt

# %%
transformed_data = np.sqrt(data['Price'])
fig, ax = plt.subplots(1,1, figsize=(12,8))
val = stats.probplot(transformed_data, plot=ax)

# %%
sns.distplot(np.sqrt(data['Price']))

# %%
sns.distplot(np.log10(np.sqrt(data['Price'])))

# %% [markdown]
# # BOXCOX transformation

# %% [markdown]
# The BoxCox transformation transforms the variable into a more gaussian-shaped distribution.

# %% [markdown]
# <font size="6">
#     \begin{equation}
# y(\lambda) =  \begin{cases}
#       \frac{y^{\lambda}-1}{\lambda} & \text{if $\lambda \neq 0$ }\\
#       \text{log} (y) & \text{if $\lambda = 0$}
#     \end{cases}
# \end{equation}
# </font>
#
# Leading to the following common transformations.
# <font size="4">
#
#
# </font>
#
# | Lambda value (λ) | BoxCox transformation (Y’) |
# |------------------|-----------------------|
# | -3               | <b>$y^{-3} $= $1/y^{3}$      </b>     |
# | -2               | <b>$y^{-2} $= $1/y^{2}$        </b>   |
# | -1               | <b>$y^{-1} $= $1/y^{1}$        </b>   |
# | -0.5             | <b>$y^{-0.5} $= 1/($\sqrt{y}$)  </b>   |
# | <span style="color:red">0 </span>               | <b><span style="color:red">$log(Y) $ </span>           </b>|
# | 0.5              | <b>$y^{0.5} $= $\sqrt{y}$       </b>   |
# | 1                | <b>$y^{1} $= y            </b>   |
# | 2                | <b>$y^{2} $               </b>   |
# | 3                | <b>$y^{3} $               </b>   |
#
# BoxCox will test the transformation that best suits your data. It will choose the one which gets closer to the normal distribution.

# %%
import numpy as np
from scipy.stats import boxcox
from scipy import stats

# %% [markdown]
# # Comparing transformations

# %%
boxcox()

# %%
# Out:
# array([32.15410118, 19.66070317, 28.9293565 , ..., 31.18216409,
#        45.32786762, 44.22724373])

# %%
#sns.distplot(data['Price'], hist=False)
sns.distplot(np.sqrt(data['Price']), hist=False, label='sqrt')
sns.distplot(boxcox(data['Price'])[0], hist=False, label='boxcox')

# %%
boxcox(x)
# Out:
# (array([-2.51672028e+00, -3.66846994e+00, -4.07255155e+00, -4.01980417e+00,
#         -2.56101271e+00, -1.34009324e+00, -6.16384700e+00, -1.45959603e+00,
#         -3.43743490e+00, -1.99697058e+00, -5.57765634e+00, -1.57756891e+00,
#         -4.48268798e+00, -8.30389257e-01, -2.03611662e+00, -2.91732041e-01,
#         -1.14457377e+00, -3.47867807e+00, -2.15237286e+00, -3.76867543e-01,
#          8.74355586e-02, -3.32777800e+00, -4.49692101e+00, -8.61117827e-01,
#         -3.20846773e+00, -4.64044711e-01, -3.71025135e+00, -3.73432673e+00,
#         -2.98087976e+00, -3.94895058e+00, -9.66799573e-01, -2.09879305e+00,
#         -6.71528830e+00, -2.14446041e+00,  1.10317609e-01,  5.89962224e-01,
#         -1.52130407e+00, -3.10160252e+00, -1.04470290e+00, -2.37495033e+00,
#          4.74758179e-02, -1.83248793e+00, -5.47793788e+00, -2.40579255e+00,
#         -3.17531481e+00,  3.62264939e-01,  5.65734246e-01, -3.90880141e+00,
# ...

# %%
fig, ax = plt.subplots(1,1, figsize=(12,8))
stats.probplot(boxcox(data['Price'])[0], plot=ax);

# %%
boxcox(data['Price'])
# Out:
# (array([32.15410118, 19.66070317, 28.9293565 , ..., 31.18216409,
#         45.32786762, 44.22724373]), 0.2635959356706707)

# %% [markdown]
# ## In future:
#
# Quantitatively check normality.
