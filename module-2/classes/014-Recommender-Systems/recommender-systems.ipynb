# %%
import matplotlib.pyplot as plt
import pandas as pd
# ^^^ pyforest auto-imports - don't write above this line
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Recommendation Systems

# %% [markdown]
# ## Content Based Recommendation Systems

# %% [markdown]
# ![content_based](content_based.png)

# %% [markdown]
# ## Collaborative Filtering Systems

# %% [markdown]
# ![collaborative_filtering](collaborative_filtering.png)

# %% [markdown]
# ## Distance
#
# Minkowski Distance

# %% [markdown]
# <font size="7">
# $$ \left(\sum_i^n|x_i - y_i|^p\right)^\frac{1}{p} $$
# </font>

# %% [markdown]
# <b> Manhattan distance (cityblock): p = 1 </b>
# $$ \sum_i^n|x_i - y_i| $$
#
#
# <b> Euclidean Distance: p = 2 </b>
# $$ \sqrt{\sum_i^n|x_i - y_i|^2} $$
#
# <b> Chebychev Distance: p $\rightarrow \infty$  </b>
# $$ \left(\sum_i^n|x_i - y_i|^\infty\right)^\frac{1}{\infty} \rightarrow max(|x_i - y_i|)$$

# %%
pd.DataFrame({'Andre':[1, 4, 4], 'Fernanda':[5, 5, 3]}, index=['Hulk','Avengers','Crepusculo']).T
# Out:
#           Hulk  Avengers  Crepusculo
# Andre        1         4           4
# Fernanda     5         5           3

# %%
np.sqrt(18)
# Out:
# 4.242640687119285

# %%
# p =1
abs(x1-x2) + abs(y1-y2)
# Out:
# 8

# %%
# p =2 
np.sqrt((x1-x2)**2 + (y1-y2)**2)
# Out:
# 5.830951894845301

# %%
# p = 100
((x1-x2)**100 + (y1-y2)**100)**(1/100)
# Out:
# 5.0

# %%
x1, y1 = (1, 5)
x2, y2 = (6, 2)


a = [x1, y1]
b = [x2, y2]

# %% [markdown]
# ## Euclidean distance

# %%
plt.scatter(x1, y1, color='k', s=50)
plt.scatter(x2, y2, color='k', s=50)
plt.grid()
plt.xlim([0, 6])
plt.ylim([0, 6])

# higher distance
plt.vlines(max(x1, x2), min(y2,y1), max(y1,y2), color='red')
plt.hlines(max(y1, y2), min(x1,x2), max(x1,x2), color='red')

plt.annotate('', xy=(x1,y1), xytext=(x2, y2), arrowprops=dict(facecolor='black', 
                                                              shrink=0,
                                                              headlength=0.0001))

print(f'Euclidean distance: {np.sqrt((x2-x1)**2 + (y2-y1)**2)}')
# Out:
# Euclidean distance: 5.830951894845301

# %% [markdown]
# ## Manhattan distance:

# %%
plt.scatter(x1, y1, color='k', s=50)
plt.scatter(x2, y2, color='k', s=50)
plt.grid()
plt.xlim([0, 6])
plt.ylim([0, 6])

# higher distance
plt.vlines(max(x1, x2), min(y2,y1), max(y1,y2), color='red')
plt.hlines(max(y1, y2), min(x1,x2), max(x1,x2), color='red')

k = 1
plt.vlines(max(x1, x2), min(y2,y1), max(y1,y2)-k, color='blue', alpha=0.5)
plt.hlines(max(y1,y2)-k, min(x1,x2), max(x1,x2), color='blue', alpha=0.5)
plt.vlines(min(x1,x2), max(y2,y1)-k, max(y1,y2), color='blue', alpha=0.5)

print(f'Manhattan distance: {abs(x2-x1) + abs(y2-y1)}')
# Out:
# Manhattan distance: 8

# %% [markdown]
# ## Cosine Distance

# %%
x1, y1 = (1, 5)
x2, y2 = (4, 2)

a = [x1, y1]
b = [x2, y2]

# %%
fig = plt.figure()

plt.scatter(x1, y1, color='k', s=50)
plt.scatter(x2, y2, color='k', s=50)
plt.grid()
plt.xlim([0, 6])
plt.ylim([0, 6])


plt.annotate('', xy=(x1,y1), xytext=(0, 0), arrowprops=dict(facecolor='black', 
                                                            
                                                            headlength=10))

plt.annotate('', xy=(x2,y2), xytext=(0, 0), arrowprops=dict(facecolor='black', 
                                                            
                                                            headlength=10))

print(f'Cosine distance: {1 - np.dot(a, b) / (np.sqrt(np.dot(a,a)) * np.sqrt(np.dot(b,b)))}')
# Out:
# Cosine distance: 0.38605938648507954

# %%
fig = plt.figure()

plt.scatter(x1, y1, color='k', s=50)
plt.scatter(x2, y2, color='k', s=50)
plt.grid()
plt.xlim([-2, 6])
plt.ylim([-2, 6])


plt.annotate('', xy=(x1,y1), xytext=(0, 0), arrowprops=dict(facecolor='black', 
                                                            
                                                            headlength=10))

plt.annotate('', xy=(x2,y2), xytext=(0, 0), arrowprops=dict(facecolor='black', 
                                                            
                                                            headlength=10))

print(f'Cosine distance: {1 - np.dot(a, b) / (np.sqrt(np.dot(a,a)) * np.sqrt(np.dot(b,b)))}')
# Out:
# Cosine distance: 0.38605938648507954

# %%
fig = plt.figure()

plt.scatter(x1, y1, color='k', s=50)
plt.scatter(x2, y2, color='k', s=50)
plt.grid()
plt.xlim([-2, 6])
plt.ylim([-2, 6])
cosine_similarity = np.dot(a, b) / (np.sqrt(np.dot(a,a)) * np.sqrt(np.dot(b,b)))

plt.annotate('', xy=(x1,y1), xytext=(0, 0), arrowprops=dict(facecolor='black', 
                                                            shrink=0,
                                                            headlength=10))

plt.annotate('', xy=(x2,y2), xytext=(0, 0), arrowprops=dict(facecolor='black', 
                                                            shrink=0,
                                                            headlength=10))

plt.annotate('', xy=(x2 * cosine_similarity * (np.dot(a,a)**.5/np.dot(b,b)**.5),  
                     y2 * cosine_similarity * (np.dot(a,a)**.5/np.dot(b,b)**.5)), xytext=(0, 0), 
                                            arrowprops=dict(facecolor='red', 
                                                            shrink=0,
                                                            headlength=10))


plt.annotate('', xy=(x2 * cosine_similarity * (np.dot(a,a)**.5/np.dot(b,b)**.5),
                     y2 * cosine_similarity * (np.dot(a,a)**.5/np.dot(b,b)**.5)), xytext=(x1, y1), 
             arrowprops={"arrowstyle" : "-", "linestyle" : "--", "linewidth" : 2, "shrinkA": 0, "shrinkB": 0})
# Out:
# Text(1, 5, '')

# %% [markdown]
# # Measuring distances in python

# %%
a = (x1,y1)
b = (x2, y2)

# %%
a
# Out:
# (1, 5)

# %%
b
# Out:
# (4, 2)

# %%
fig = plt.figure()

plt.scatter(x1, y1, color='k', marker='s', s=100)
plt.scatter(x2, y2, color='k', marker='s', s=100)
plt.grid()
plt.xlim([0, 6])
plt.ylim([0, 6])

plt.annotate('a',np.array(a) + (0.15, 0.15));
plt.annotate('b',np.array(b) + (0.15, 0.15));

# %% [markdown]
# ## Using sklearn

# %%
from sklearn.metrics import pairwise_distances

pairwise_distances([a, b])
# Out:
# array([[0.        , 4.24264069],
#        [4.24264069, 0.        ]])

# %%
pd.DataFrame(pairwise_distances([a, b]), index=['a','b'], columns=['a','b'])
# Out:
#           a         b
# a  0.000000  4.242641
# b  4.242641  0.000000

# %%
from sklearn.metrics import pairwise_distances

pairwise_distances([a, b], 
                   metric='cosine')
# Out:
# array([[0.00000000e+00, 3.86059386e-01],
#        [3.86059386e-01, 1.11022302e-16]])

# %%
from sklearn.metrics import pairwise_distances

pairwise_distances([a,b], 
                   metric='cityblock')
# Out:
# array([[0., 6.],
#        [6., 0.]])

# %% [markdown]
# ## Using scipy

# %%
from scipy.spatial.distance import pdist, squareform

pdist([a,b], 'euclidean')
# Out:
# array([4.24264069])

# %%
squareform(pdist([a, b], 'euclidean'))
# Out:
# array([[0.        , 4.24264069],
#        [4.24264069, 0.        ]])

# %%
pd.DataFrame(squareform(pdist([a, b], 'cityblock')), index=['a','b'], columns=['a','b'])
# Out:
#      a    b
# a  0.0  6.0
# b  6.0  0.0

# %% [markdown]
# ## Correlation Distances

# %%
df = pd.read_csv('clustered_crimes.csv', index_col=0).drop('cluster', axis=1)

# %%
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# index
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
from sklearn.preprocessing import StandardScaler, scale

# %%
X_std = pd.DataFrame(scale(df), columns=df.columns, index=df.index)
X_std
# Out:
#                   Murder   Assault  UrbanPop      Rape
# index
# Alabama         1.255179  0.790787 -0.526195 -0.003451
# Alaska          0.513019  1.118060 -1.224067  2.509424
# Arizona         0.072361  1.493817  1.009122  1.053466
# Arkansas        0.234708  0.233212 -1.084492 -0.186794
# California      0.281093  1.275635  1.776781  2.088814
# Colorado        0.025976  0.402909  0.869548  1.883901
# Connecticut    -1.040880 -0.736484  0.799761 -1.092723
# Delaware       -0.437875  0.815030  0.450825 -0.585834
# Florida         1.765415  1.990786  1.009122  1.150530
# Georgia         2.229265  0.487757 -0.386621  0.492653
# Hawaii         -0.577030 -1.512241  1.218484 -0.111300
# Idaho          -1.203228 -0.615272 -0.805344 -0.758392
# Illinois        0.605789  0.948363  1.218484  0.298525
# Indiana        -0.136372 -0.700121 -0.037685 -0.025021
# Iowa           -1.295998 -1.391029 -0.595982 -1.071153
# Kansas         -0.414682 -0.675878  0.032102 -0.348567
# Kentucky        0.443441 -0.748605 -0.944918 -0.531910
# Louisiana       1.765415  0.948363  0.032102  0.104398
# Maine          -1.319191 -1.063757 -1.014705 -1.448624
# Maryland        0.814521  1.566544  0.101889  0.708350
# Massachusetts  -0.785763 -0.263757  1.358058 -0.531910
# Michigan        1.000062  1.021090  0.590399  1.495646
# Minnesota      -1.180036 -1.197090  0.032102 -0.682898
# Massachusetts    27.843312
# Michigan         97.161412
# Minnesota        89.298936
# Mississippi      99.743371
# Missouri         23.507446
# Montana          52.481235
# Nebraska         59.093654
# Nevada           98.363205
# New Hampshire   104.361391
# New Jersey       29.250641
# New Mexico      125.576311
# New York         97.230345
# North Carolina  176.747532
# North Dakota    117.545268
# Ohio             44.044182
# Oklahoma         13.542526
# Oregon           15.630099
# Pennsylvania     56.300444
# Rhode Island     31.029824
# South Carolina  119.051963
# South Dakota     76.595300
# Tennessee        29.977492
# Texas            46.182464
# Utah             46.338429
# Vermont         116.591252
# Virginia          7.930952
# Washington       23.349518
# West Virginia    82.957218
# Wisconsin       108.354418
# Wyoming           0.000000
#
# [50 rows x 50 columns]

# %%
pd.DataFrame(squareform(pdist(X_std, metric='euclidean')), 
             columns=df.index,
             index=df.index,).style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col1 {
#             background-color:  #6dc072;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col2 {
#             background-color:  #86cc85;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col3 {
#             background-color:  #abdda5;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col4 {
#             background-color:  #63bc6e;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col5 {
#             background-color:  #63bc6e;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col6 {
#             background-color:  #349d53;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col7 {
#             background-color:  #62bb6d;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col8 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col9 {
#             background-color:  #cbebc5;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col10 {
#             background-color:  #2b934b;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col11 {
#             background-color:  #45ad5f;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col12 {
#             background-color:  #9ed798;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col13 {
#             background-color:  #55b567;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col14 {
#             background-color:  #38a156;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col15 {
#             background-color:  #4db163;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col16 {
#             background-color:  #8bcf89;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col17 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col18 {
#             background-color:  #3fa95c;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col19 {
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col20 {
#             background-color:  #339c52;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col21 {
#             background-color:  #a4da9e;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col22 {
#             background-color:  #349d53;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col23 {
#             background-color:  #bce4b5;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col24 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col25 {
#             background-color:  #63bc6e;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col26 {
#             background-color:  #43ac5e;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col27 {
#             background-color:  #6ec173;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col28 {
#             background-color:  #38a156;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col29 {
#             background-color:  #46ae60;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col30 {
#             background-color:  #b1e0ab;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col31 {
#             background-color:  #98d594;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col32 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col33 {
#             background-color:  #369f54;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col34 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col35 {
#             background-color:  #56b567;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col36 {
#             background-color:  #359e53;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col37 {
#             background-color:  #46ae60;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col38 {
#             background-color:  #369f54;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col39 {
#             background-color:  #d3eecd;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col40 {
#             background-color:  #4bb062;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col41 {
#             background-color:  #d2edcc;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col42 {
#             background-color:  #aadda4;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col43 {
#             background-color:  #29914a;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col44 {
#             background-color:  #3aa357;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col45 {
#             background-color:  #86cc85;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col46 {
#             background-color:  #309950;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col47 {
#             background-color:  #58b668;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col48 {
#             background-color:  #329b51;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row0_col49 {
#             background-color:  #80ca80;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col0 {
#             background-color:  #37a055;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col2 {
#             background-color:  #68be70;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col3 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col4 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col5 {
#             background-color:  #7dc87e;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col6 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col7 {
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col8 {
#             background-color:  #76c578;
#             color:  #000000;
#         }    #T_51df7cda_9322_11ea_b298_001a7dda7113row1_col9 {
#             background-color:  #

# %%
pd.DataFrame(squareform(pdist(X_std, metric='euclidean')), 
             columns=df.index,
             index=df.index,).loc[['California']].T.sort_values(by='California').style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_67a2768c_9322_11ea_9da9_001a7dda7113row0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row1_col0 {
#             background-color:  #d4eece;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row2_col0 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row3_col0 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row4_col0 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row5_col0 {
#             background-color:  #bee5b8;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row6_col0 {
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row7_col0 {
#             background-color:  #b2e0ac;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row8_col0 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row9_col0 {
#             background-color:  #a5db9f;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row10_col0 {
#             background-color:  #a3da9d;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row11_col0 {
#             background-color:  #9fd899;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row12_col0 {
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row13_col0 {
#             background-color:  #84cc83;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row14_col0 {
#             background-color:  #83cb82;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row15_col0 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row16_col0 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row17_col0 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row18_col0 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row19_col0 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row20_col0 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row21_col0 {
#             background-color:  #6bc072;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row22_col0 {
#             background-color:  #66bd6f;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row23_col0 {
#             background-color:  #66bd6f;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row24_col0 {
#             background-color:  #63bc6e;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row25_col0 {
#             background-color:  #5bb86a;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row26_col0 {
#             background-color:  #5ab769;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row27_col0 {
#             background-color:  #4bb062;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row28_col0 {
#             background-color:  #48ae60;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row29_col0 {
#             background-color:  #45ad5f;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row30_col0 {
#             background-color:  #43ac5e;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row31_col0 {
#             background-color:  #42ab5d;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row32_col0 {
#             background-color:  #42ab5d;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row33_col0 {
#             background-color:  #3ca559;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row34_col0 {
#             background-color:  #37a055;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row35_col0 {
#             background-color:  #359e53;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row36_col0 {
#             background-color:  #2e964d;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row37_col0 {
#             background-color:  #2e964d;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row38_col0 {
#             background-color:  #2d954d;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row39_col0 {
#             background-color:  #2b934b;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row40_col0 {
#             background-color:  #278f48;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row41_col0 {
#             background-color:  #248c46;
#             color:  #000000;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row42_col0 {
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row43_col0 {
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row44_col0 {
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row45_col0 {
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row46_col0 {
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row47_col0 {
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row48_col0 {
#             background-color:  #004d1f;
#             color:  #f1f1f1;
#         }    #T_67a2768c_9322_11ea_9da9_001a7dda7113row49_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_67a2768c_9322_11ea_9da9_001a7dda7113" ><thead>    <tr>        <th class="index_name level0" >index</th>        <th class="col_heading level0 col0" >California</th>    </tr>    <tr>        <th class="index_name level0" >index</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67a2768c_9322_11ea_9da9_001a7dda7113level0_row0" class="row_heading level0 row0" >California</th>
#                         <td id="T_67a2768c_9322_11ea_9da9_001a7dda7113row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_67a2768c_9322_11ea_9da9_001a7dda7113level0_row1" class="row_heading level0 row1" >Nevada</th>
#                         <td id="T_67a2768c_9322_11ea_9da9_001a7dda7113row1_col0" class="data row1 col0" >1.208977</td>
#             </tr>
#             <tr>
#                         <th id="T_67a2768c_9322_11ea_9da9_001a7dda7113level0_row2" class="row_heading level0 row2" >Colorado</th>
#                         <td id="T_67a2768c_9322_11ea_9da9_001a7dda7113row2_col0" class="data row2 col0" >1.300691</td>
#             </tr>
#             <tr>
#                         <th id="T_67a2768c_9322_11ea_9da9_001a7dda7113level0_row3" class="row_heading le

# %%
plt.plot(X_std.loc['California', :], label='California')
plt.plot(X_std.loc['Nevada', :], label='Nevada')
plt.legend()

# %%
plt.plot(X_std.loc['California', :], label='California')
plt.plot(X_std.loc['Vermont', :], label='Vermont')
plt.legend()

# %%
pd.DataFrame(squareform(pdist(X_std, metric='cosine')), 
             columns=df.index,
             index=df.index,).loc[['Pennsylvania']].T.sort_values(by='Pennsylvania').style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_a865c380_9326_11ea_b166_001a7dda7113row0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row1_col0 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row2_col0 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row3_col0 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row4_col0 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row5_col0 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row6_col0 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row7_col0 {
#             background-color:  #e5f5e1;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row8_col0 {
#             background-color:  #e4f5df;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row9_col0 {
#             background-color:  #e4f5df;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row10_col0 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row11_col0 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row12_col0 {
#             background-color:  #e0f3db;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row13_col0 {
#             background-color:  #def2d9;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row14_col0 {
#             background-color:  #d5efcf;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row15_col0 {
#             background-color:  #d4eece;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row16_col0 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row17_col0 {
#             background-color:  #caeac3;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row18_col0 {
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row19_col0 {
#             background-color:  #bde5b6;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row20_col0 {
#             background-color:  #bbe4b4;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row21_col0 {
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row22_col0 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row23_col0 {
#             background-color:  #aadda4;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row24_col0 {
#             background-color:  #a3da9d;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row25_col0 {
#             background-color:  #97d492;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row26_col0 {
#             background-color:  #83cb82;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row27_col0 {
#             background-color:  #7cc87c;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row28_col0 {
#             background-color:  #4aaf61;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row29_col0 {
#             background-color:  #37a055;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row30_col0 {
#             background-color:  #339c52;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row31_col0 {
#             background-color:  #309950;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row32_col0 {
#             background-color:  #208843;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row33_col0 {
#             background-color:  #1d8640;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row34_col0 {
#             background-color:  #1c8540;
#             color:  #000000;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row35_col0 {
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row36_col0 {
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row37_col0 {
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row38_col0 {
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row39_col0 {
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row40_col0 {
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row41_col0 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row42_col0 {
#             background-color:  #006b2b;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row43_col0 {
#             background-color:  #006b2b;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row44_col0 {
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row45_col0 {
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row46_col0 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row47_col0 {
#             background-color:  #005020;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row48_col0 {
#             background-color:  #004d1f;
#             color:  #f1f1f1;
#         }    #T_a865c380_9326_11ea_b166_001a7dda7113row49_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_a865c380_9326_11ea_b166_001a7dda7113" ><thead>    <tr>        <th class="index_name level0" >index</th>        <th class="col_heading level0 col0" >Pennsylvania</th>    </tr>    <tr>        <th class="index_name level0" >index</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a865c380_9326_11ea_b166_001a7dda7113level0_row0" class="row_heading level0 row0" >Pennsylvania</th>
#                         <td id="T_a865c380_9326_11ea_b166_001a7dda7113row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_a865c380_9326_11ea_b166_001a7dda7113level0_row1" class="row_heading level0 row1" >Connecticut</th>
#                         <td id="T_a865c380_9326_11ea_b166_001a7dda7113row1_col0" class="data row1 col0" >0.072790</td>
#             </tr>
#             <tr>
#                         <th id="T_a865c380_9326_11ea_b166_001a7dda7113level0_row2" class="row_heading level0 row2" >Kansas</th>
#                         <td id="T_a865c380_9326_11ea_b166_001a7dda7113row2_col0" class="data row2 col0" >0.098509</td>
#             </tr>
#             <tr>
#                         <th id="T_a865c380_9326_11ea_b166_001a7dda7113level0_row3" class="row_hea

# %%
plt.plot(X_std.loc['Pennsylvania', :], label='Pennsylvania')
plt.plot(X_std.loc['Michigan', :], label='Michigan')
plt.legend()

# %%
plt.plot(X_std.loc['California', :], label='California')
plt.plot(X_std.loc['Washington', :], label='Washington')
plt.legend()

# %% [markdown]
# # Applications: Measuring real distances

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

ratings = pd.read_csv('movie_ratings.csv').set_index('Movie').T

# %%
ratings
# Out:
# Movie     Aquaman  Avengers: Infinity War  Black Panther  Bohemian Rhapsody  \
# Brandon         4                       2              5                  2
# Emily           1                       5              2                  3
# Cleo            2                       2              5                  4
# Rusty           2                       5              1                  4
# Samantha        2                       5              1                  1
#
# Movie     Deadpool 2  Fantastic Beasts: The Crimes of Grindelwald  \
# Brandon            3                                            5
# Emily              2                                            4
# Cleo               4                                            1
# Rusty              5                                            2
# Samantha           1                                            5
#
# Movie     Incredibles 2  Jurassic World: Fallen Kingdom  \
# Brandon               4                               2
# Emily                 2                               3
# Cleo                  3                               5
# Rusty                 4                               4
# Samantha              4                               5
#
# Movie     Mission: Impossible – Fallout  Venom
# Brandon                               5      4
# Emily                                 5      1
# Cleo                                  4      4
# Rusty                                 3      5
# Samantha                              2      2

# %%
def ratings_scatter(movie1, movie2):
    x = ratings.loc[:, movie1]
    y = ratings.loc[:, movie2]
    n = list(ratings.index)

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.scatter(x, y, s=50, marker='x')
    plt.title(f"Preference Space for {movie1} vs. {movie2}", fontsize=20)
    plt.grid()
    ax.set_xlabel(movie1, fontsize=16)
    ax.set_ylabel(movie2, fontsize=16) 

    for i, txt in enumerate(n):
        
        ax.annotate(txt, (x[i], y[i]), fontsize=12)

# %%
ratings_scatter('Venom', 'Incredibles 2')

# %%
pd.DataFrame(
    squareform(
        pdist(ratings[['Venom', 'Incredibles 2', 'Bohemian Rhapsody']])), 
    columns=ratings.index, index=ratings.index)
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   0.000000  3.741657  2.236068  2.236068  2.236068
# Emily     3.741657  0.000000  3.316625  4.582576  3.000000
# Cleo      2.236068  3.316625  0.000000  1.414214  3.741657
# Rusty     2.236068  4.582576  1.414214  0.000000  4.242641
# Samantha  2.236068  3.000000  3.741657  4.242641  0.000000

# %%
pd.DataFrame(
    squareform(
        pdist(ratings)), 
    columns=ratings.index, index=ratings.index)
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   0.000000  6.633250  6.000000  7.416198  7.483315
# Emily     6.633250  0.000000  6.928203  6.403124  5.099020
# Cleo      6.000000  6.928203  0.000000  5.567764  8.246211
# Rusty     7.416198  6.403124  5.567764  0.000000  6.708204
# Samantha  7.483315  5.099020  8.246211  6.708204  0.000000

# %%
from scipy.spatial.distance import pdist, squareform

squareform(pdist(ratings, 'cityblock'))
# Out:
# array([[ 0., 18., 14., 21., 20.],
#        [18.,  0., 20., 17., 14.],
#        [14., 20.,  0., 13., 22.],
#        [21., 17., 13.,  0., 15.],
#        [20., 14., 22., 15.,  0.]])

# %%
ratings
# Out:
# Movie     Aquaman  Avengers: Infinity War  Black Panther  Bohemian Rhapsody  \
# Brandon         4                       2              5                  2
# Emily           1                       5              2                  3
# Cleo            2                       2              5                  4
# Rusty           2                       5              1                  4
# Samantha        2                       5              1                  1
#
# Movie     Deadpool 2  Fantastic Beasts: The Crimes of Grindelwald  \
# Brandon            3                                            5
# Emily              2                                            4
# Cleo               4                                            1
# Rusty              5                                            2
# Samantha           1                                            5
#
# Movie     Incredibles 2  Jurassic World: Fallen Kingdom  \
# Brandon               4                               2
# Emily                 2                               3
# Cleo                  3                               5
# Rusty                 4                               4
# Samantha              4                               5
#
# Movie     Mission: Impossible – Fallout  Venom
# Brandon                               5      4
# Emily                                 5      1
# Cleo                                  4      4
# Rusty                                 3      5
# Samantha                              2      2

# %%
pdist(ratings, 'euclidean')
# Out:
# array([6.63324958, 6.        , 7.41619849, 7.48331477, 6.92820323,
#        6.40312424, 5.09901951, 5.56776436, 8.24621125, 6.70820393])

# %%
# pairwise distance
distance = squareform(pdist(ratings, 'euclidean'))
distance
# Out:
# array([[0.        , 6.63324958, 6.        , 7.41619849, 7.48331477],
#        [6.63324958, 0.        , 6.92820323, 6.40312424, 5.09901951],
#        [6.        , 6.92820323, 0.        , 5.56776436, 8.24621125],
#        [7.41619849, 6.40312424, 5.56776436, 0.        , 6.70820393],
#        [7.48331477, 5.09901951, 8.24621125, 6.70820393, 0.        ]])

# %%
pd.DataFrame(distance, index=ratings.index, columns=ratings.index)
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   0.000000  6.633250  6.000000  7.416198  7.483315
# Emily     6.633250  0.000000  6.928203  6.403124  5.099020
# Cleo      6.000000  6.928203  0.000000  5.567764  8.246211
# Rusty     7.416198  6.403124  5.567764  0.000000  6.708204
# Samantha  7.483315  5.099020  8.246211  6.708204  0.000000

# %%
1/(1 + squareform(distance))
# Out:
# array([0.1310058 , 0.14285714, 0.11881849, 0.11787845, 0.12613198,
#        0.13507811, 0.16396078, 0.15225881, 0.10815241, 0.12973191])

# %%
ratings
# Out:
# Movie     Aquaman  Avengers: Infinity War  Black Panther  Bohemian Rhapsody  \
# Brandon         4                       2              5                  2
# Emily           1                       5              2                  3
# Cleo            2                       2              5                  4
# Rusty           2                       5              1                  4
# Samantha        2                       5              1                  1
#
# Movie     Deadpool 2  Fantastic Beasts: The Crimes of Grindelwald  \
# Brandon            3                                            5
# Emily              2                                            4
# Cleo               4                                            1
# Rusty              5                                            2
# Samantha           1                                            5
#
# Movie     Incredibles 2  Jurassic World: Fallen Kingdom  \
# Brandon               4                               2
# Emily                 2                               3
# Cleo                  3                               5
# Rusty                 4                               4
# Samantha              4                               5
#
# Movie     Mission: Impossible – Fallout  Venom
# Brandon                               5      4
# Emily                                 5      1
# Cleo                                  4      4
# Rusty                                 3      5
# Samantha                              2      2

# %%
similarity_index = pd.DataFrame(1/(1 + squareform(pdist(ratings))), index=ratings.index, columns=ratings.index)
similarity_index
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   1.000000  0.131006  0.142857  0.118818  0.117878
# Emily     0.131006  1.000000  0.126132  0.135078  0.163961
# Cleo      0.142857  0.126132  1.000000  0.152259  0.108152
# Rusty     0.118818  0.135078  0.152259  1.000000  0.129732
# Samantha  0.117878  0.163961  0.108152  0.129732  1.000000

# %%
def create_similarity(dataframe, metric='euclidean'):
    
    distance_vector = pdist(dataframe, metric)
    distance_matrix = squareform(distance_vector)
    similarities = 1 / (1 + distance_matrix)
    
    similarity_index = pd.DataFrame(similarities, 
                                    index=dataframe.index, 
                                    columns=dataframe.index)
    return similarity_index

# %%
create_similarity(ratings)
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   1.000000  0.131006  0.142857  0.118818  0.117878
# Emily     0.131006  1.000000  0.126132  0.135078  0.163961
# Cleo      0.142857  0.126132  1.000000  0.152259  0.108152
# Rusty     0.118818  0.135078  0.152259  1.000000  0.129732
# Samantha  0.117878  0.163961  0.108152  0.129732  1.000000

# %%
new_person = {'Aquaman': 2,
              'Avengers: Infinity War': 1,
              'Black Panther': 5,
              'Bohemian Rhapsody': 5,
              'Deadpool 2': 2,
              'Fantastic Beasts: The Crimes of Grindelwald': 3,
              'Incredibles 2': 3,
              'Jurassic World: Fallen Kingdom': 4,
              'Mission: Impossible – Fallout': 3,
              'Venom': 3}

# %%
ratings
# Out:
# Movie     Aquaman  Avengers: Infinity War  Black Panther  Bohemian Rhapsody  \
# Brandon         4                       2              5                  2
# Emily           1                       5              2                  3
# Cleo            2                       2              5                  4
# Rusty           2                       5              1                  4
# Samantha        2                       5              1                  1
#
# Movie     Deadpool 2  Fantastic Beasts: The Crimes of Grindelwald  \
# Brandon            3                                            5
# Emily              2                                            4
# Cleo               4                                            1
# Rusty              5                                            2
# Samantha           1                                            5
#
# Movie     Incredibles 2  Jurassic World: Fallen Kingdom  \
# Brandon               4                               2
# Emily                 2                               3
# Cleo                  3                               5
# Rusty                 4                               4
# Samantha              4                               5
#
# Movie     Mission: Impossible – Fallout  Venom
# Brandon                               5      4
# Emily                                 5      1
# Cleo                                  4      4
# Rusty                                 3      5
# Samantha                              2      2

# %%
person = pd.DataFrame(pd.Series(new_person, name='Andre')).T
person
# Out:
#        Aquaman  Avengers: Infinity War  Black Panther  Bohemian Rhapsody  \
# Andre        2                       1              5                  5
#
#        Deadpool 2  Fantastic Beasts: The Crimes of Grindelwald  Incredibles 2  \
# Andre           2                                            3              3
#
#        Jurassic World: Fallen Kingdom  Mission: Impossible – Fallout  Venom
# Andre                               4                              3      3

# %%
merged_dataframe = pd.concat([ratings, person], axis=0)
merged_dataframe
# Out:
# Movie     Aquaman  Avengers: Infinity War  Black Panther  Bohemian Rhapsody  \
# Brandon         4                       2              5                  2
# Emily           1                       5              2                  3
# Cleo            2                       2              5                  4
# Rusty           2                       5              1                  4
# Samantha        2                       5              1                  1
# Andre           2                       1              5                  5
#
# Movie     Deadpool 2  Fantastic Beasts: The Crimes of Grindelwald  \
# Brandon            3                                            5
# Emily              2                                            4
# Cleo               4                                            1
# Rusty              5                                            2
# Samantha           1                                            5
# Andre              2                                            3
#
# Movie     Incredibles 2  Jurassic World: Fallen Kingdom  \
# Brandon               4                               2
# Emily                 2                               3
# Cleo                  3                               5
# Rusty                 4                               4
# Samantha              4                               5
# Andre                 3                               4
#
# Movie     Mission: Impossible – Fallout  Venom
# Brandon                               5      4
# Emily                                 5      1
# Cleo                                  4      4
# Rusty                                 3      5
# Samantha                              2      2
# Andre                                 3      3

# %%
similarities = create_similarity(merged_dataframe)
similarities
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha     Andre
# Brandon   1.000000  0.131006  0.142857  0.118818  0.117878  0.156613
# Emily     0.131006  1.000000  0.126132  0.135078  0.163961  0.135078
# Cleo      0.142857  0.126132  1.000000  0.152259  0.108152  0.217129
# Rusty     0.118818  0.135078  0.152259  1.000000  0.129732  0.126132
# Samantha  0.117878  0.163961  0.108152  0.129732  1.000000  0.116961
# Andre     0.156613  0.135078  0.217129  0.126132  0.116961  1.000000

# %%
similarities['Andre']
# Out:
# Brandon     0.156613
# Emily       0.135078
# Cleo        0.217129
# Rusty       0.126132
# Samantha    0.116961
# Andre       1.000000
# Name: Andre, dtype: float64

# %%
similarities['Andre'].drop('Andre')
# Out:
# Brandon     0.156613
# Emily       0.135078
# Cleo        0.217129
# Rusty       0.126132
# Samantha    0.116961
# Name: Andre, dtype: float64

# %%
new_ratings = pd.read_csv('movie_ratings2.csv').set_index('Movie')

# %%
new_ratings
# Out:
#                                 Brandon  Emily  Cleo  Rusty  Samantha
# Movie
# Beauty and the Beast                  2      5     2      5         2
# Despicable Me 3                       4      5     5      1         2
# Guardians of the Galaxy Vol. 2        4      1     5      4         2
# Jumanji: Welcome to the Jungle        4      3     3      2         5
# Spider-Man: Homecoming                1      3     5      2         5
# Star Wars: The Last Jedi              5      4     1      2         2
# The Fate of the Furious               2      1     3      3         3
# Thor: Ragnarok                        4      3     4      1         5
# Wolf Warrior 2                        5      3     2      3         4
# Wonder Woman                          4      3     4      3         4

# %%
recommendations = new_ratings.copy()

# %%
recommendations
# Out:
#                                 Brandon  Emily  Cleo  Rusty  Samantha
# Movie
# Beauty and the Beast                  2      5     2      5         2
# Despicable Me 3                       4      5     5      1         2
# Guardians of the Galaxy Vol. 2        4      1     5      4         2
# Jumanji: Welcome to the Jungle        4      3     3      2         5
# Spider-Man: Homecoming                1      3     5      2         5
# Star Wars: The Last Jedi              5      4     1      2         2
# The Fate of the Furious               2      1     3      3         3
# Thor: Ragnarok                        4      3     4      1         5
# Wolf Warrior 2                        5      3     2      3         4
# Wonder Woman                          4      3     4      3         4

# %%
similarities['Andre'].drop('Andre')
# Out:
# Brandon     0.156613
# Emily       0.135078
# Cleo        0.217129
# Rusty       0.126132
# Samantha    0.116961
# Name: Andre, dtype: float64

# %%
for name, score in dict(similarities['Andre'].drop('Andre')).items():
    # contribuição de todos os meus amigos, ponderados pela distância deles para mim (score)
    recommendations[name] = recommendations[name] * score

# %%
recommendations
# Out:
#                                  Brandon     Emily      Cleo     Rusty  \
# Movie
# Beauty and the Beast            0.313226  0.675391  0.434259  0.630660
# Despicable Me 3                 0.626452  0.675391  1.085646  0.126132
# Guardians of the Galaxy Vol. 2  0.626452  0.135078  1.085646  0.504528
# Jumanji: Welcome to the Jungle  0.626452  0.405234  0.651388  0.252264
# Spider-Man: Homecoming          0.156613  0.405234  1.085646  0.252264
# Star Wars: The Last Jedi        0.783065  0.540312  0.217129  0.252264
# The Fate of the Furious         0.313226  0.135078  0.651388  0.378396
# Thor: Ragnarok                  0.626452  0.405234  0.868517  0.126132
# Wolf Warrior 2                  0.783065  0.405234  0.434259  0.378396
# Wonder Woman                    0.626452  0.405234  0.868517  0.378396
#
#                                 Samantha
# Movie
# Beauty and the Beast            0.233923
# Despicable Me 3                 0.233923
# Guardians of the Galaxy Vol. 2  0.233923
# Jumanji: Welcome to the Jungle  0.584807
# Spider-Man: Homecoming          0.584807
# Star Wars: The Last Jedi        0.233923
# The Fate of the Furious         0.350884
# Thor: Ragnarok                  0.584807
# Wolf Warrior 2                  0.467845
# Wonder Woman                    0.467845

# %%
recommendations['Total'] = recommendations.sum(axis=1)
recommendations.sort_values('Total', ascending=False)
# Out:
#                                  Brandon     Emily      Cleo     Rusty  \
# Movie
# Despicable Me 3                 0.626452  0.675391  1.085646  0.126132
# Wonder Woman                    0.626452  0.405234  0.868517  0.378396
# Thor: Ragnarok                  0.626452  0.405234  0.868517  0.126132
# Guardians of the Galaxy Vol. 2  0.626452  0.135078  1.085646  0.504528
# Jumanji: Welcome to the Jungle  0.626452  0.405234  0.651388  0.252264
# Spider-Man: Homecoming          0.156613  0.405234  1.085646  0.252264
# Wolf Warrior 2                  0.783065  0.405234  0.434259  0.378396
# Beauty and the Beast            0.313226  0.675391  0.434259  0.630660
# Star Wars: The Last Jedi        0.783065  0.540312  0.217129  0.252264
# The Fate of the Furious         0.313226  0.135078  0.651388  0.378396
#
#                                 Samantha     Total
# Movie
# Despicable Me 3                 0.233923  2.747544
# Wonder Woman                    0.467845  2.746445
# Thor: Ragnarok                  0.584807  2.611142
# Guardians of the Galaxy Vol. 2  0.233923  2.585627
# Jumanji: Welcome to the Jungle  0.584807  2.520145
# Spider-Man: Homecoming          0.584807  2.484564
# Wolf Warrior 2                  0.467845  2.468799
# Beauty and the Beast            0.233923  2.287458
# Star Wars: The Last Jedi        0.233923  2.026693
# The Fate of the Furious         0.350884  1.828972

# %% [markdown]
# # Compare different types of distances

# %%
create_similarity(ratings)
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   1.000000  0.131006  0.142857  0.118818  0.117878
# Emily     0.131006  1.000000  0.126132  0.135078  0.163961
# Cleo      0.142857  0.126132  1.000000  0.152259  0.108152
# Rusty     0.118818  0.135078  0.152259  1.000000  0.129732
# Samantha  0.117878  0.163961  0.108152  0.129732  1.000000

# %%
#manhattan distance
create_similarity(ratings, 'cityblock')
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   1.000000  0.052632  0.066667  0.045455  0.047619
# Emily     0.052632  1.000000  0.047619  0.055556  0.066667
# Cleo      0.066667  0.047619  1.000000  0.071429  0.043478
# Rusty     0.045455  0.055556  0.071429  1.000000  0.062500
# Samantha  0.047619  0.066667  0.043478  0.062500  1.000000

# %%
create_similarity(ratings, 'cosine')
# Out:
#            Brandon     Emily      Cleo     Rusty  Samantha
# Brandon   1.000000  0.857174  0.885260  0.838267  0.823128
# Emily     0.857174  1.000000  0.833399  0.863703  0.887485
# Cleo      0.885260  0.833399  1.000000  0.898415  0.780388
# Rusty     0.838267  0.863703  0.898415  1.000000  0.851898
# Samantha  0.823128  0.887485  0.780388  0.851898  1.000000
