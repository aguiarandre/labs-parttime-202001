# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('diamonds_clean.csv')

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
diamonds_gb_color = diamonds.groupby('color')
diamonds_gb_color['price'].describe()
# Out:
#          count         mean          std    min      25%     50%     75%  \
# color
# D       6159.0  3162.202468  3342.211976  357.0   911.00  1828.0  4205.0
# E       8869.0  3091.383020  3358.203543  326.0   888.00  1746.0  4027.0
# F       8651.0  3722.164490  3781.130713  342.0   982.00  2340.0  4852.0
# G      10285.0  3989.929995  4039.176023  354.0   931.00  2215.0  6048.0
# H       7540.0  4475.434748  4218.182245  337.0   977.00  3437.0  5975.0
# I       4889.0  5121.677848  4731.475968  334.0  1134.00  3767.0  7256.0
# J       2540.0  5342.467323  4441.118287  335.0  1874.75  4271.5  7695.0
#
#            max
# color
# D      18693.0
# E      18731.0
# F      18791.0
# G      18818.0
# H      18803.0
# I      18823.0
# J      18710.0

# %%
# Price seems not to have a strong correlation based just upon color

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
diamonds.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col1 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col3 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col4 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col5 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col6 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col7 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow0_col9 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col0 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col2 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col3 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col4 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col5 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col6 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col7 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow1_col9 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col0 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col3 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col4 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col5 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col6 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col7 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col8 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col0 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col4 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col5 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col6 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col7 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col8 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow3_col9 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col0 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col2 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col3 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col5 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col6 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col8 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow4_col9 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col0 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col1 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col2 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col3 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col4 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col6 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col7 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col8 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_aa48e87a_a2e1_11ea_8733_5cea1dd695derow5_col9 {
#             background-color:  #d8d7e9;
#             color:  #000000;

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
diamonds_gb_color.mean()
# Out:
#           carat      depth      table        price         x         y  \
# color
# D      0.656904  61.707891  57.384868  3162.202468  5.415491  5.419706
# E      0.658942  61.660785  57.490585  3091.383020  5.413941  5.421500
# F      0.736225  61.701607  57.420425  3722.164490  5.616532  5.620319
# G      0.770016  61.757540  57.290170  3989.929995  5.676257  5.678986
# H      0.909698  61.833515  57.518740  4475.434748  5.980141  5.982452
# I      1.030982  61.853078  57.570239  5121.677848  6.230671  6.230626
# J      1.164531  61.888268  57.798701  5342.467323  6.523567  6.523402
#
#               z  clarity_idx  color_idx   cut_idx
# color
# D      3.342418     2.695730        6.0  2.933106
# E      3.342300     2.975871        5.0  2.896042
# F      3.466205     3.139984        4.0  2.886140
# G      3.506356     3.470102        3.0  2.989985
# H      3.696404     2.937003        2.0  2.881432
# I      3.851678     2.958069        1.0  2.879935
# J      4.036268     2.778740        0.0  2.735039

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
diamonds.color_idx.plot(kind = 'hist')

# %%
#your comments here

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
diamonds_gb_carat = diamonds.groupby('carat')
diamonds_gb_carat.mean()
# Out:
#            depth      table         price          x          y         z  \
# carat
# 0.20   60.866667  59.333333    364.555556   3.792222   3.758889  2.297778
# 0.21   60.511111  58.444444    380.222222   3.874444   3.837778  2.332222
# 0.22   60.750000  60.250000    405.000000   3.905000   3.865000  2.360000
# 0.23   61.402612  58.026119    486.776119   3.946903   3.974403  2.430970
# 0.24   61.600000  57.563559    502.860169   3.989661   4.018263  2.465085
# ...          ...        ...           ...        ...        ...       ...
# 3.67   62.400000  56.000000  16193.000000   9.860000   9.810000  6.130000
# 4.00   63.300000  58.000000  15984.000000  10.010000   9.940000  6.310000
# 4.01   61.750000  61.500000  15223.000000  10.080000  10.020000  6.205000
# 4.50   65.800000  58.000000  18531.000000  10.230000  10.160000  6.720000
# 5.01   65.500000  59.000000  18018.000000  10.740000  10.540000  6.980000
#
#        clarity_idx  color_idx   cut_idx
# carat
# 0.20      2.777778   5.222222  3.222222
# 0.21      2.666667   5.444444  2.888889
# 0.22      2.500000   4.750000  3.000000
# 0.23      4.884328   4.507463  2.276119
# 0.24      4.953390   4.211864  2.533898
# ...            ...        ...       ...
# 3.67      0.000000   1.000000  3.000000
# 4.00      0.000000   1.000000  2.000000
# 4.01      0.000000   0.500000  3.000000
# 4.50      0.000000   0.000000  0.000000
# 5.01      0.000000   0.000000  0.000000
#
# [270 rows x 9 columns]

# %%
#your comments

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
diamonds.carat.plot(kind = 'hist')

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
diamonds_gb_table = diamonds.groupby('table')
diamonds_gb_table.mean()
# Out:
#         carat  depth    price      x      y      z  clarity_idx  color_idx  \
# table
# 43.0   1.0400  62.90   4997.0  6.450  6.410  4.040         4.00        1.0
# 44.0   0.2900  62.80    474.0  4.200  4.240  2.650         4.00        5.0
# 49.0   0.6500  64.25   2290.5  5.355  5.320  3.425         3.00        3.0
# 50.0   1.0200  61.80   4227.0  6.590  6.510  4.050         2.00        4.0
# 50.1   0.9400  66.00   3353.0  6.130  6.170  4.060         1.00        2.0
# ...       ...    ...      ...    ...    ...    ...          ...        ...
# 71.0   0.6800  58.00   1633.0  5.850  5.700  3.350         2.00        3.0
# 73.0   0.6025  68.90   2406.5  5.520  5.465  3.745         3.25        4.5
# 76.0   0.7900  65.30   2362.0  5.520  5.130  3.350         2.00        3.0
# 79.0   0.8100  68.80   2301.0  5.260  5.200  3.580         1.00        4.0
# 95.0   2.0100  58.60  13387.0  8.320  8.310  4.870         2.00        4.0
#
#        cut_idx
# table
# 43.0       4.0
# 44.0       2.0
# 49.0       0.0
# 50.0       0.0
# 50.1       0.0
# ...        ...
# 71.0       0.0
# 73.0       0.0
# 76.0       0.0
# 79.0       0.0
# 95.0       0.0
#
# [124 rows x 9 columns]

# %%
#your comments here

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
diamonds_gb_clarity = diamonds.groupby('clarity')
diamonds_gb_clarity.mean()
# Out:
#             carat      depth      table        price         x         y  \
# clarity
# I1       1.282644  62.761702  58.297720  3931.088146  6.758328  6.706337
# IF       0.507247  61.501674  56.488159  2874.269684  4.974743  4.996696
# SI1      0.851919  61.855544  57.657598  4006.569726  5.892237  5.891973
# SI2      1.079403  61.772977  57.922676  5079.631021  6.406593  6.402712
# VS1      0.725340  61.668676  57.304766  3822.993824  5.569633  5.580231
# VS2      0.764359  61.729003  57.413755  3926.107165  5.659131  5.660504
# VVS1     0.502684  61.634548  56.872711  2518.059036  4.960771  4.975431
# VVS2     0.594947  61.666063  57.032449  3273.212082  5.215448  5.228803
#
#                 z  clarity_idx  color_idx   cut_idx
# clarity
# I1       4.224548          0.0   2.969605  1.989362
# IF       3.065356          7.0   3.088655  3.442033
# SI1      3.643030          2.0   3.450135  2.748394
# SI2      3.954109          1.0   3.468088  2.667510
# VS1      3.440377          4.0   3.173469  3.000000
# VS2      3.493251          3.0   3.489077  2.980221
# VVS1     3.062090          6.0   3.357831  3.231024
# VVS2     3.219579          5.0   3.576483  3.122330

# %%
#your comments here

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
# Price seems to have strong correlations just in X and Carat

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
# Not so, since it show us correlation also in Y and Z

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8504653718934192

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
