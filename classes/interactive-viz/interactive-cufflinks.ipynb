# %%
# install cufflinks version 0.16.0

# %%
# !pip install cufflinks==0.16.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('./data/churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['MonthlyCharges'] = pd.to_numeric(df['MonthlyCharges'], errors='coerce')
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# # Histogram

# %%
df['TotalCharges'].plot(kind='hist')

# %%
df['TotalCharges'].iplot(kind='hist', title='Total Charges Histogram', xTitle='Total Charges', yTitle='Frequency')
# Out:
# <div>
#
#
#             <div id="984aeca9-1efd-4443-b93b-26d33cb79b8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("984aeca9-1efd-4443-b93b-26d33cb79b8a")) {
#                     Plotly.newPlot(
#                         '984aeca9-1efd-4443-b93b-26d33cb79b8a',
# ...

# %% [markdown]
# # Bar plot

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# create variable ChurnBinary (1-0) based on Churn (Yes-No)
df['ChurnBinary'] = df['Churn'].apply(lambda x : 1 if x == 'Yes' else 0)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
# get the average of churn for each payment method
data = df.groupby('PaymentMethod', as_index=False)['ChurnBinary'].mean()

# %%
data
# Out:
#                PaymentMethod  ChurnBinary
# 0  Bank transfer (automatic)     0.167098
# 1    Credit card (automatic)     0.152431
# 2           Electronic check     0.452854
# 3               Mailed check     0.191067

# %%
data.plot(kind='bar', x='PaymentMethod')

# %%
data.iplot(kind='bar', x='PaymentMethod')
# Out:
# <div>
#
#
#             <div id="fcfa7c0d-9986-44f4-b2a9-ce9a6bba6884" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fcfa7c0d-9986-44f4-b2a9-ce9a6bba6884")) {
#                     Plotly.newPlot(
#                         'fcfa7c0d-9986-44f4-b2a9-ce9a6bba6884',
# ...

# %% [markdown]
# # Line Plot

# %%
# tenure: tempo de casa

data = df.groupby('tenure', as_index=False).agg({'ChurnBinary':'mean'})

# %%
data.head()
# Out:
#    tenure  ChurnBinary
# 0       0     0.000000
# 1       1     0.619902
# 2       2     0.516807
# 3       3     0.470000
# 4       4     0.471591

# %%
data.plot(kind='line', x='tenure')

# %%
data.iplot(kind='line', x='tenure')
# Out:
# <div>
#
#
#             <div id="8d89b1ed-0532-4fdd-831e-8daf53262ca6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8d89b1ed-0532-4fdd-831e-8daf53262ca6")) {
#                     Plotly.newPlot(
#                         '8d89b1ed-0532-4fdd-831e-8daf53262ca6',
# ...

# %% [markdown]
# # Scatter Plot

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
data = df.query('Contract == "One year" and PaymentMethod == "Credit card (automatic)"')

# %%
data.iplot(x='tenure', y='TotalCharges', mode='markers')
# Out:
# <div>
#
#
#             <div id="d0d136fd-ef8c-4655-9a26-f699d999e111" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d0d136fd-ef8c-4655-9a26-f699d999e111")) {
#                     Plotly.newPlot(
#                         'd0d136fd-ef8c-4655-9a26-f699d999e111',
# ...

# %%
data.iplot(x='tenure', y='TotalCharges', mode='markers', categories='InternetService')
# Out:
# <div>
#
#
#             <div id="af088c2a-a956-41ec-91ce-0876f2877365" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("af088c2a-a956-41ec-91ce-0876f2877365")) {
#                     Plotly.newPlot(
#                         'af088c2a-a956-41ec-91ce-0876f2877365',
# ...

# %%
py

# %%
fig, axes = plt.subplots(1,2, figsize=(12,8))

data.iplot(x='tenure', y='TotalCharges', mode='markers', categories='InternetService', ax= axes[0])
# Out:
# <div>
#
#
#             <div id="bcadcc69-4767-431b-b2f0-1510b418b672" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bcadcc69-4767-431b-b2f0-1510b418b672")) {
#                     Plotly.newPlot(
#                         'bcadcc69-4767-431b-b2f0-1510b418b672',
# ...

# %% [markdown]
# # Bubble

# %%
data = data.query('PhoneService == "No"')

data.iplot(kind='bubble', x='tenure', y='MonthlyCharges', size='TotalCharges',xTitle='Tenure',
           categories='gender')
# Out:
# <div>
#
#
#             <div id="b9a1a78c-ef4f-4b33-a844-9b903ab6eae4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b9a1a78c-ef4f-4b33-a844-9b903ab6eae4")) {
#                     Plotly.newPlot(
#                         'b9a1a78c-ef4f-4b33-a844-9b903ab6eae4',
# ...

# %%
df[[ 'TotalCharges']].iplot(kind='box', )
# Out:
# <div>
#
#
#             <div id="d2df5f62-2fe6-446a-978e-0b078b91c10e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d2df5f62-2fe6-446a-978e-0b078b91c10e")) {
#                     Plotly.newPlot(
#                         'd2df5f62-2fe6-446a-978e-0b078b91c10e',
# ...

# %% [markdown]
# # IPyWidgets

# %%
from ipywidgets import interact

# %%
df['TotalCharges'].iplot(kind='hist', bins=50, title='Tenure Distribution')
# Out:
# <div>
#
#
#             <div id="37f498e6-b4ec-451e-8eaf-abea58899a11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("37f498e6-b4ec-451e-8eaf-abea58899a11")) {
#                     Plotly.newPlot(
#                         '37f498e6-b4ec-451e-8eaf-abea58899a11',
# ...

# %%
def plot_graph(bins):
    df['TotalCharges'].iplot(kind='hist', bins=bins, title='Tenure Distribution')

# %%
interact(plot_graph, bins=(5,50, 5))
# Out:
# interactive(children=(IntSlider(value=25, description='bins', max=50, min=5, step=5), Output()), _dom_classes=…
# <function __main__.plot_graph(bins)>

# %%
@interact(bins = (5, 50, 5))
def plot_graph(bins):
    df['TotalCharges'].iplot(kind='hist', bins=bins, title='Tenure Distribution')
# Out:
# interactive(children=(IntSlider(value=25, description='bins', max=50, min=5, step=5), Output()), _dom_classes=…

# %%
@interact(churn = [True, False])
def plot_graph(churn):
    
    data = df.query(f'ChurnBinary == {churn}')
    
    data['TotalCharges'].iplot(kind='hist', bins=50, title='Tenure Distribution')
# Out:
# interactive(children=(Dropdown(description='churn', options=(True, False), value=True), Output()), _dom_classe…

# %%
@interact(Gender=list(df['gender'].unique()), 
          Partner=list(df['Partner'].unique()),
          Internet=list(df['InternetService'].unique()), 
          Payment=list(df['PaymentMethod'].unique())
         )

def scatter(Gender, Partner, Internet, Payment):
    data = df[(df['gender']==Gender) & 
              (df['Partner']==Partner) & 
              (df['InternetService']==Internet) & 
              (df['PaymentMethod']==Payment)]

    data.iplot(kind='scatter', x='tenure', y='MonthlyCharges', 
               categories='Contract', text='customerID', 
               xTitle='Tenure', yTitle='Monthly Charges',
               title='Charges vs. Tenure')
# Out:
# interactive(children=(Dropdown(description='Gender', options=('Female', 'Male'), value='Female'), Dropdown(des…

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
#
#       PaymentMethod MonthlyCharges TotalCharges  Churn  ChurnBinary
# 0  Electronic check          29.85        29.85     No            0
# 1      Mailed check          56.95      1889.50     No            0
#
# [2 rows x 22 columns]

# %%
df.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['PaymentMethod'].apply(lambda x : re.search('check', x, flags=re.IGNORECASE))

# %%
@interact(Payment='')

def chart(Payment):
    
    import re
    df['PaymentMethod'].apply(lambda x : re.search(Payment, flags=re.IGNORECASE))
    data = df.loc[df['PaymentMethod'].str.contains(Payment)]
    data = data.groupby('InternetService').agg({'MonthlyCharges':'sum'}).reset_index()
    custom_dict = {'New': 0, 'Regular': 1, 'Loyal': 2, 'Very Loyal' : 3}  
    data = data.iloc[data['InternetService'].argsort()].set_index('InternetService')
    
    data.iplot(kind='bar', xTitle='Values')
# Out:
# interactive(children=(Text(value='', description='Payment'), Output()), _dom_classes=('widget-interact',))
