# %% [markdown]
# # Pandas QUICK REVIEW

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Series

# %% [markdown]
# Can be thought as generalized 1-D numpy arrays with index flexibility.

# %% [markdown]
# **index** is the key with which you access the value of the row of the pandas series.

# %%
my_series = pd.Series({'a': 10, 'b':20, 'e':30})
my_series
# Out:
# a    10
# b    20
# e    30
# dtype: int64

# %%
my_series['e']
# Out:
# 30

# %%
my_second_series = pd.Series({'a': 50, 'b':300, 'e':23})
my_third_series = pd.Series({'a': 530, 'b':20, 'e':48923})

# %%
my_second_series
# Out:
# a     50
# b    300
# e     23
# dtype: int64

# %% [markdown]
# Can be thought as a dictionary with respect to the observations (rows)

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# This can be thought as a generalized 2-D numpy array.

# %% [markdown]
# **columns** is the key with which you access the whole column of a dataframe.

# %% [markdown]
# Also can be thought as a composition of many pandas Series:

# %%
my_dataframe = pd.DataFrame({'series_A': my_series, 
                             'series_B': my_second_series,
                             'series_C': my_third_series})
my_dataframe
# Out:
#    series_A  series_B  series_C
# a        10        50       530
# b        20       300        20
# e        30        23     48923

# %% [markdown]
# So a dataframe can be thought as a dictionary with respect to columns (columns)

# %%
my_dataframe['series_A']
# Out:
# a    10
# b    20
# e    30
# Name: series_A, dtype: int64

# %%
qualquer_variavel = my_dataframe[['series_A', 'series_C']]

# %%
qualquer_variavel
# Out:
#    series_A  series_C
# a        10       530
# b        20        20
# e        30     48923

# %% [markdown]
# ## Math operations

# %%
my_dataframe.mean()
# Out:
# series_A       20.000000
# series_B      124.333333
# series_C    16491.000000
# dtype: float64

# %%
my_dataframe.mean(axis=1)
# Out:
# a      196.666667
# b      113.333333
# e    16325.333333
# dtype: float64

# %%
my_dataframe.head(2)
# Out:
#    series_A  series_B  series_C
# a        10        50       530
# b        20       300        20

# %%
my_dataframe.tail(2)
# Out:
#    series_A  series_B  series_C
# b        20       300        20
# e        30        23     48923

# %%
my_dataframe.sample(2)
# Out:
#    series_A  series_B  series_C
# b        20       300        20
# e        30        23     48923

# %%
my_dataframe.T
# Out:
#             a    b      e
# series_A   10   20     30
# series_B   50  300     23
# series_C  530   20  48923

# %%
my_dataframe.max()
# Out:
# series_A       30
# series_B      300
# series_C    48923
# dtype: int64

# %%
my_dataframe.min()
# Out:
# series_A    10
# series_B    23
# series_C    20
# dtype: int64

# %% [markdown]
# ------

# %% [markdown]
# # Pandas: Importing and Exporting

# %%
import os

# %%
os.listdir('data/')
# Out:
# ['.DS_Store',
#  'vehicles_tab.txt',
#  'vehicles_pipe.txt',
#  'vehicles.json',
#  'vehicles.xlsx',
#  'vehicles_messy.csv',
#  'vehicles.csv']

# %% [markdown]
# ## IMPORTING AND EXPORTING DELIMITED FILES

# %% [markdown]
# ### Comma separated files
#
# A file that is separated (or delimited) by commas (or anything else)

# %% [markdown]
# Example:
#
# **-- comma separated file --**
#
#     name,year,value
#     Andre,2020,100
#     Fernanda,1900,1
#
# **-- tab separated file --**
#
#     name    year    value
#     Andre    2020    100
#     Fernanda    1900    1
#
# **-- tab separated file (another way) --**
#
#     name\tyear\tvalue
#     Andre\t2020\t100
#     Fernanda\t1900\t1
#
# **-- hash separated file --**
#
#     name#year#value
#     Andre#2020#100
#     Fernanda#1900#1
#
# **-- pipe separated file --**
#
#     name|year|value
#     Andre|2020|100
#     Fernanda|1900|1
#
#     ...

# %% [markdown]
# ### Import comma-separated variable file (the default)

# %%
pd.read_csv('data/vehicles.csv')
# in this way, the pd.read_csv() function is just outputing the results in the screen.
# If I wanted to store it in a variable I would have to assign this result into a variable
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
# !pwd
# Out:
# /Users/andreaguiar/Desktop/usr/dev/ironhack/ironhack-analytics/import-export-data

# %%
df = pd.read_csv('data/vehicles.csv')

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# ## Import tab-delimited file

# %%
# print('\ta')

# %%
pd.read_csv('data/vehicles_tab.txt', sep='\t')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# ## Import pipe delimited file

# %%
df = pd.read_csv('data/vehicles_pipe.txt', sep='|')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
# hash
df = pd.read_csv('data/vehicles_hash.txt', sep='#')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# # Importing Excel FIles

# %%
pd.read_excel('data/vehicles.xlsx')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0              4  Automatic 3-spd     2-Wheel Drive
# 1              6  Automatic 3-spd     2-Wheel Drive
# 2              4  Automatic 3-spd  Rear-Wheel Drive
# 3              6  Automatic 3-spd  Rear-Wheel Drive
# 4              6  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947          3        Auto(AM5)  Rear-Wheel Drive
# 35948          3        Auto(AM5)  Rear-Wheel Drive
# 35949          3        Auto(AM5)  Rear-Wheel Drive
# 35950          3        Auto(AM6)  Rear-Wheel Drive
# 35951          3     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# ## Read from specific excel sheet

# %%
df = pd.read_excel('data/dados_artigo1.xlsx', sheet_name='dataset')
df.head()
# Out:
#    unplanted3   planted3  unplanted7   planted7  unplanted10  planted10  \
# 0    0.000000  78.636959   84.820995  52.068175    84.783652  85.310734
# 1    0.000000  14.616304   14.015557   0.000000    40.375704  28.928829
# 2   80.511993  89.752898   87.460473  89.376096    94.163425  87.193210
# 3   75.900402  87.403649   80.646947  93.727934    93.886463  94.274587
# 4   15.042991  69.794541   49.785408  82.442805    17.340252  78.333261
#
#   wether  parameter       date
# 0    wet  turbidity 2018-02-09
# 1    wet  turbidity 2018-02-15
# 2    wet  turbidity 2018-02-22
# 3    wet  turbidity 2018-03-01
# 4    wet  turbidity 2018-03-08

# %% [markdown]
# # Exporting datasets

# %% [markdown]
# ## Export TO CSV

# %%
df.head()
# Out:
#    unplanted3   planted3  unplanted7   planted7  unplanted10  planted10  \
# 0    0.000000  78.636959   84.820995  52.068175    84.783652  85.310734
# 1    0.000000  14.616304   14.015557   0.000000    40.375704  28.928829
# 2   80.511993  89.752898   87.460473  89.376096    94.163425  87.193210
# 3   75.900402  87.403649   80.646947  93.727934    93.886463  94.274587
# 4   15.042991  69.794541   49.785408  82.442805    17.340252  78.333261
#
#   wether  parameter       date
# 0    wet  turbidity 2018-02-09
# 1    wet  turbidity 2018-02-15
# 2    wet  turbidity 2018-02-22
# 3    wet  turbidity 2018-03-01
# 4    wet  turbidity 2018-03-08

# %%
df.to_csv('data/exported_file_v2.csv', index=False)

# %%
# pd.read_csv('data/exported_file_v2.csv', index_col=0)
# Out:
#      unplanted3    planted3  unplanted7    planted7  unplanted10   planted10  \
# 0      0.000000   78.636959   84.820995   52.068175    84.783652   85.310734
# 1      0.000000   14.616304   14.015557    0.000000    40.375704   28.928829
# 2     80.511993   89.752898   87.460473   89.376096    94.163425   87.193210
# 3     75.900402   87.403649   80.646947   93.727934    93.886463   94.274587
# 4     15.042991   69.794541   49.785408   82.442805    17.340252   78.333261
# ..          ...         ...         ...         ...          ...         ...
# 215   65.309446   87.153652   74.054054   86.700913    63.328034   91.534091
# 216    0.000000   48.520710   38.206278    0.000000    34.740545   71.739130
# 217   28.395062   83.783784   66.559486  100.000000   100.000000  100.000000
# 218   59.640103  100.000000   44.281525  100.000000   100.000000  100.000000
# 219   10.194175  100.000000  100.000000  100.000000   100.000000  100.000000
#
#     wether  parameter        date
# 0      wet  turbidity  2018-02-09
# 1      wet  turbidity  2018-02-15
# 2      wet  turbidity  2018-02-22
# 3      wet  turbidity  2018-03-01
# 4      wet  turbidity  2018-03-08
# ..     ...        ...         ...
# 215    wet         pt  2018-10-05
# 216    wet         pt  2018-10-11
# 217    wet         pt  2018-10-18
# 218    wet         pt  2018-10-25
# 219    wet         pt  2018-10-31
#
# [220 rows x 9 columns]

# %% [markdown]
# **NOTE**: If you do not specify the argument `index=False`, the output in the csv file will create an unnamed index column with the *dataframe indexes*.

# %%
df.to_csv('data/exported_file.csv', index=False)

# %% [markdown]
# ## Export to csv using a specific separator

# %% [markdown]
# ### Semicolon

# %%
df.to_csv('data/exported_file_semicolon.csv', index=False, sep=';')

# %% [markdown]
# ### Pipe

# %%
df.to_csv('data/exported_file_pipe.csv', index=False, sep='|')

# %% [markdown]
# ### plust or minus

# %%
df.to_csv('data/exported_file_plusminus.csv', index=False, sep='±')

# %% [markdown]
# # Import and export JSON files

# %%
data = pd.read_json('data/vehicles.json')

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# For a JSON file, you can have different `orient` options.
#
# `'split'`: Dictionary containing indexes, columns, and data.
#
# `'index'`: Nested dictionaries containing {index:{column:value}}.
#
# `'columns'`: Nested dictionaries containing {column:{index:value}}
#
# `'values'`: Nested list where each sublist contains the values for a record.
#
# `'table'`: Nested dictionaries containing schema and data (records).

# %%
data.sample(10).to_json('data/vehicles_split.json', orient='split')
data.sample(10).to_json('data/vehicles_index.json', orient='index')
data.sample(10).to_json('data/vehicles_columns.json', orient='columns')
data.sample(10).to_json('data/vehicles_values.json', orient='values')
data.sample(10).to_json('data/vehicles_table.json', orient='table')

# %%
data.sample(10)
# Out:
#                Make               Model  Year  Engine Displacement  Cylinders  \
# 27144        Nissan           Truck 4WD  1995                  2.4          4
# 3027            BMW         Z4 Roadster  2005                  3.0          6
# 1600            BMW    325i Convertible  1990                  2.5          6
# 4407      Chevrolet  Avalanche 1500 2WD  2003                  5.3          8
# 400    Aston Martin                 DB9  2014                  5.9         12
# 468    Aston Martin          V8 Vantage  2013                  4.7          8
# 4811      Chevrolet    C2500 Pickup 2WD  1991                  5.7          8
# 5563      Chevrolet            Corvette  2012                  6.2          8
# 21270         Lexus          IS 250 AWD  2015                  2.5          6
# 12192          Ford              Escort  1985                  2.0          4
#
#           Transmission                  Drivetrain  \
# 27144     Manual 5-spd  4-Wheel or All-Wheel Drive
# 3027    Automatic (S5)            Rear-Wheel Drive
# 1600   Automatic 4-spd            Rear-Wheel Drive
# 4407   Automatic 4-spd            Rear-Wheel Drive
# 400     Automatic (S6)            Rear-Wheel Drive
# 468          Auto(AM7)            Rear-Wheel Drive
# 4811      Manual 4-spd            Rear-Wheel Drive
# 5563      Manual 6-spd            Rear-Wheel Drive
# 21270   Automatic (S6)             All-Wheel Drive
# 12192     Manual 5-spd           Front-Wheel Drive
#
#                      Vehicle Class        Fuel Type  Fuel Barrels/Year  \
# 27144       Standard Pickup Trucks          Regular          19.388824
# 3027                   Two Seaters          Premium          16.480500
# 1600               Subcompact Cars          Regular          18.311667
# 4407   Sport Utility Vehicle - 2WD  Gasoline or E85          23.543571
# 400               Minicompact Cars          Premium          21.974000
# 468                    Two Seaters          Premium          20.600625
# 4811        Standard Pickup Trucks          Regular          25.354615
# 5563                   Two Seaters          Premium          19.388824
# 21270                 Compact Cars          Premium          14.330870
# 12192                 Compact Cars           Diesel           9.554625
#
#        City MPG  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 27144        16           19            17               522.764706
# 3027         17           25            20               444.350000
# 1600         16           21            18               493.722222
# 4407         13           17            14               634.785714
# 400          13           19            15               588.000000
# 468          14           21            16               551.000000
# 4811         12           14            13               683.615385
# 5563         14           21            17               522.764706
# 21270        20           27            23               389.000000
# 12192        36           46            40               254.500000
#
#        Fuel Cost/Year
# 27144            1950
# 3027             2000
# 1600             1850
# 4407             2400
# 400              2700
# 468              2550
# 4811             2550
# 5563             2400
# 21270            1750
# 12192             900

# %%
df = data.head(12)

# %%
df.to_csv('data/teste.csv')

# %%
pd.read_csv('data/CSV.8859-1.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-87-972b05dc3fba> in <module>
# ----> 1 pd.read_csv('data/CSV.8859-1.csv', encoding='utf-8')
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 406: invalid continuation byte

# %%
pd.read_csv('data/CSV.8859-1.csv', encoding='latin-1', sep=';')
# Out:
#           Data Projeto(s)    Ini    Ter  Horas  \
# 0   qui, 02/01        GTE  11:30  12:00  00:30
# 1   qui, 02/01        GTE  13:00  13:30  00:30
# 2   qui, 02/01        GTE  13:30  14:00  00:30
# 3   qui, 02/01   GTE - FC  14:00  15:00  01:00
# 4   qui, 02/01        GTE  15:00  15:30  00:30
# ..         ...        ...    ...    ...    ...
# 93  qua, 29/01    PRODESP  16:30  17:30  01:00
# 94  qui, 30/01    PRODESP  14:00  18:00  04:00
# 95  sex, 31/01         RS  10:30  12:00  01:30
# 96  sex, 31/01        GTE  12:00  12:30  00:30
# 97  sex, 31/01    PRODESP  13:30  14:30  01:00
#
#                               Atividade  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0               Tarefas administrativas         NaN         NaN         NaN
# 1                  Apontamento de horas         NaN         NaN         NaN
# 2               Tarefas administrativas         NaN         NaN         NaN
# 3   Troubleshooting Contrato X Rubricas         NaN         NaN         NaN
# 4               Tarefas administrativas         NaN         NaN         NaN
# ..                                  ...         ...         ...         ...
# 93                       Sistemas APESP         NaN         NaN         NaN
# 94                       Sistemas APESP         NaN         NaN         NaN
# 95                  Revisão query Inova         NaN         NaN         NaN
# 96              Tarefas administrativas         NaN         NaN         NaN
# 97                       Sistemas APESP         NaN         NaN         NaN
#
#     Unnamed: 9
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
# [98 rows x 10 columns]

# %%
pd.read_csv('data/CSV.UTF8.csv', sep=';')
# Out:
#           Data Projeto(s)    Ini    Ter  Horas  \
# 0   qui, 02/01        GTE  11:30  12:00  00:30
# 1   qui, 02/01        GTE  13:00  13:30  00:30
# 2   qui, 02/01        GTE  13:30  14:00  00:30
# 3   qui, 02/01   GTE - FC  14:00  15:00  01:00
# 4   qui, 02/01        GTE  15:00  15:30  00:30
# ..         ...        ...    ...    ...    ...
# 93  qua, 29/01    PRODESP  16:30  17:30  01:00
# 94  qui, 30/01    PRODESP  14:00  18:00  04:00
# 95  sex, 31/01         RS  10:30  12:00  01:30
# 96  sex, 31/01        GTE  12:00  12:30  00:30
# 97  sex, 31/01    PRODESP  13:30  14:30  01:00
#
#                               Atividade  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0               Tarefas administrativas         NaN         NaN         NaN
# 1                  Apontamento de horas         NaN         NaN         NaN
# 2               Tarefas administrativas         NaN         NaN         NaN
# 3   Troubleshooting Contrato X Rubricas         NaN         NaN         NaN
# 4               Tarefas administrativas         NaN         NaN         NaN
# ..                                  ...         ...         ...         ...
# 93                       Sistemas APESP         NaN         NaN         NaN
# 94                       Sistemas APESP         NaN         NaN         NaN
# 95                  Revisão query Inova         NaN         NaN         NaN
# 96              Tarefas administrativas         NaN         NaN         NaN
# 97                       Sistemas APESP         NaN         NaN         NaN
#
#     Unnamed: 9
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
# [98 rows x 10 columns]

# %%
data.iloc[100:200]
# Out:
#       Make   Model  Year  Engine Displacement  Cylinders     Transmission  \
# 100  Acura  Legend  1989                  2.7          6     Manual 5-spd
# 101  Acura  Legend  1990                  2.7          6  Automatic 4-spd
# 102  Acura  Legend  1990                  2.7          6     Manual 5-spd
# 103  Acura  Legend  1991                  3.2          6  Automatic 4-spd
# 104  Acura  Legend  1991                  3.2          6     Manual 5-spd
# ..     ...     ...   ...                  ...        ...              ...
# 195  Acura      RL  2008                  3.5          6   Automatic (S5)
# 196  Acura      RL  2009                  3.7          6   Automatic (S5)
# 197  Acura      RL  2010                  3.7          6   Automatic (S5)
# 198  Acura      RL  2011                  3.7          6   Automatic (S6)
# 199  Acura      RL  2012                  3.7          6   Automatic (S6)
#
#                      Drivetrain Vehicle Class Fuel Type  Fuel Barrels/Year  \
# 100           Front-Wheel Drive  Compact Cars   Regular          17.347895
# 101           Front-Wheel Drive  Compact Cars   Regular          18.311667
# 102           Front-Wheel Drive  Compact Cars   Regular          17.347895
# 103           Front-Wheel Drive  Compact Cars   Premium          18.311667
# 104           Front-Wheel Drive  Compact Cars   Premium          17.347895
# ..                          ...           ...       ...                ...
# 195  4-Wheel or All-Wheel Drive  Midsize Cars   Premium          17.347895
# 196  4-Wheel or All-Wheel Drive  Midsize Cars   Premium          18.311667
# 197             All-Wheel Drive  Midsize Cars   Premium          18.311667
# 198             All-Wheel Drive  Midsize Cars   Premium          16.480500
# 199             All-Wheel Drive  Midsize Cars   Premium          16.480500
#
#      City MPG  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 100        17           22            19               467.736842
# 101        16           20            18               493.722222
# 102        17           22            19               467.736842
# 103        17           21            18               493.722222
# 104        16           24            19               467.736842
# ..        ...          ...           ...                      ...
# 195        16           24            19               467.736842
# 196        16           22            18               493.722222
# 197        16           22            18               493.722222
# 198        17           24            20               444.350000
# 199        17           24            20               444.350000
#
#      Fuel Cost/Year
# 100            1750
# 101            1850
# 102            1750
# 103            2250
# 104            2150
# ..              ...
# 195            2150
# 196            2250
# 197            2250
# 198            2000
# 199            2000
#
# [100 rows x 15 columns]

# %%
data.loc[100:200, ['Make','Year']]
# Out:
#       Make  Year
# 100  Acura  1989
# 101  Acura  1990
# 102  Acura  1990
# 103  Acura  1991
# 104  Acura  1991
# ..     ...   ...
# 196  Acura  2009
# 197  Acura  2010
# 198  Acura  2011
# 199  Acura  2012
# 200  Acura  2014
#
# [101 rows x 2 columns]
